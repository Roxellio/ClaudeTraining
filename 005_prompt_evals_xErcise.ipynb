# %%
# base
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic() 
model = "claude-haiku-4-5"

# %%
# Helpers
def add_user_message(messages, text):
  user_message = {
    "role": "user", 
    "content": text
  }
  messages.append(user_message)

def add_assistant_message(messages, text):
  assistant_message = {
    "role": "assistant",
    "content": text
  }
  messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
  params= {
    "model": model,
    "max_tokens": 1000,
    "messages": messages,
    "temperature": temperature,
    "stop_sequences": stop_sequences
  }

  if system:
    params["system"] = system

  message = client.messages.create(**params)
  return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Give criteria on how to solve this task. Don't make these criteria too long"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# generate dataset
# dataset = generate_dataset()
# with open("dataset.json", "w") as f:
#   json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
  """Merges the prompt and test case input, then returns the result"""
  prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""
  messages = []
  add_user_message(messages, prompt)
  # uses ```code if unknown whether it'd returns ```python, ```bash, ```json, ```regex, etc`
  add_assistant_message(messages, "```code")
  output = chat(
    messages,
    stop_sequences=["```"]
  )
  return output

# %%
# grade_by_model from text based guide, high possibility of returning error/wrong since it's using like completely different variables
# replaced previously {task} and {solution} to {test_case} and {output} accordingly. Might need to test this function too
def grade_by_model_0(test_case, output):
  eval_prompt = f"""
You are an expert code reviewer. Evaluate this AI-generated solution.

Task: {test_case["task"]}
Solution: {output}

Provide your evaluation as a structured JSON object with:
- "strenghts": An array of 1-3 key strength
- "weaknesses": An array of 1-3 key areas of improvements
- "reasoning" "A concise explanation of your assessment
- "score": A number between 1-10
"""

  messages = []
  add_user_message(messages, eval_prompt)
  add_assistant_message(messages, "```json")

  eval_text = chat(messages, stop_sequences=["```"])
  return json.loads(eval_text)

# %%
# Model Validator - grading by using models (basically using AI to score them results)
def grade_by_model(test_case, output):
  eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Solution Criteria:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strenghts
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment. Make sure to explain whether solution criterias specified are met or not
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
  "strengths": string[],
  "weaknesses": string[],
  "reasoning": string,
  "score": number
}}
"""
  
  messages = []
  add_user_message(messages, eval_prompt)
  add_assistant_message(messages, "```json")
  eval_text = chat(messages, stop_sequences=["```"])
  return json.loads(eval_text)

# %%
# code validators

import ast
import re

def validate_json(text):
  try:
    json.loads((text.strip()))
    return 10
  except json.JSONDecodeError:
    return 0
  
def validate_python(text):
  try:
    ast.parse(text.strip())
    return 10
  except SyntaxError:
    return 0
  
def validate_regex(text):
  try:
    re.compile(text.strip())
    return 10
  except re.error:
    return 0
  
def grade_syntax(response, test_case):
  format = test_case["format"]

  match format:
    case "json":
      return validate_json(response)
    case "python":
      return validate_python(response)
    case "regex":
      return validate_regex(response)
    case _:
      return 0 # because of it's unkown format

# %%
def run_test_case(test_case):
  """Calls run_prompt, then grades the result"""
  output = run_prompt(test_case)
  
  model_grade = grade_by_model(test_case, output)
  model_score = model_grade["score"]
  model_reasoning = model_grade["reasoning"]
  syntax_score = grade_syntax(output, test_case)

  score = (model_score + syntax_score)/2

  return {
    "output": output,
    "test_case": test_case,
    # "model_score": model_grade["score"],
    # "reasoning": model_grade["reasoning"],
    # can skip strength & weakness to avoid being too long
    # "strength": model_grade["strengths"],
    # "weaknesses": model_grade["weaknesses"]
    # "model_score": model_score,
    "score": score,
    "reasoning": model_reasoning,
    # "syntax_score": syntax_score
  }

# %%
from statistics import mean

def run_eval(dataset):
  """Loads the dataset and calls run_test_case with each case"""
  results = []

  for test_case in dataset:
    result = run_test_case(test_case)
    results.append(result)

  average_score = mean([result["score"] for result in results])
  print(f"Average score: {average_score}")


  return results

# %%
with open("dataset.json", "r") as f:
  dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.166666666666666

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\n\ndef extract_s3_bucket(uri):\n    match = re.match(r's3://([^/]+)', uri)\n    return match.group(1) if match else None\n\n# Example usage\nprint(extract_s3_bucket('s3://my-bucket/path/to/file.txt'))\n",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from a full S3 URI (e.g., 's3://my-bucket/path/to/file.txt') and extract only the bucket name",
#       "format": "regex",
#       "solution_criteria": "Use a regex pattern to match and capture the bucket name between 's3://' and the first forward slash. The bucket name should contain only alphanumeric characters, hyphens, and periods."
#     },
#     "score": 7.5,
#     "reasoning": "The solution meets the basic functional requirement of extracting bucket names from S3 URIs using regex. However, it fails to fully meet the specified criteria because the regex pattern `[^/]+` is too permissive\u2014it matches any character except forward slashes, rather than restricting to alphanumeric characters, hyphens, and periods as explicitly required. The correct pattern should be `[a-z0-9.-]+` to enforce valid S3 bucket naming rules. While the implementation works for well-formed inputs, it would incorrectly accept invalid bucket names containing special characters, and lacks defensive programming practices."
#   },
#   {
#     "output": "\n{\n  \"FunctionName\": \"my-lambda-function\",\n  \"Runtime\": \"python3.11\",\n  \"Timeout\": 30,\n  \"MemorySize\": 256,\n  \"Environment\": {\n    \"Variables\": {\n      \"DB_CONNECTION_STRING\": \"postgresql://user:password@localhost:5432/database\"\n    }\n  }\n}\n",
#     "test_case": {
#       "task": "Create a JSON configuration object for an AWS Lambda function that specifies the function name, runtime (Python 3.11), timeout (30 seconds), memory (256 MB), and an environment variable for a database connection string",
#       "format": "json",
#       "solution_criteria": "Generate a valid JSON object with appropriate keys for Lambda configuration. Include nested objects/arrays where necessary and ensure all values are properly typed (strings, numbers, objects)."
#     },
#     "score": 8.5,
#     "reasoning": "The solution meets the specified criteria by providing a valid JSON object with all requested configuration elements (function name, runtime, timeout, memory, and environment variable) with proper typing and nested structure. However, there is a significant security concern: storing database credentials directly in the configuration is a major vulnerability. In production environments, sensitive data like connection strings should be stored in AWS Secrets Manager or encrypted in Systems Manager Parameter Store, with environment variables pointing to those secure references instead. The core JSON structure is correct and would function, but the implementation exposes security risks."
#   },
#   {
#     "output": "\nimport json\nfrom typing import Any, Union\n\ndef extract_message_from_cloudwatch_event(event: dict) -> Union[str, None]:\n    \"\"\"\n    Extracts the message field from an AWS CloudWatch log event.\n    \n    Args:\n        event: CloudWatch log event dictionary\n        \n    Returns:\n        The message string if found, None otherwise\n    \"\"\"\n    # Check for message in awslogs compressed data\n    if 'awslogs' in event and 'data' in event['awslogs']:\n        try:\n            import gzip\n            import base64\n            \n            compressed_data = base64.b64decode(event['awslogs']['data'])\n            decompressed_data = gzip.decompress(compressed_data)\n            log_data = json.loads(decompressed_data)\n            \n            if 'logEvents' in log_data and len(log_data['logEvents']) > 0:\n                return log_data['logEvents'][0].get('message')\n        except Exception:\n            pass\n    \n    # Check for direct message field\n    if 'message' in event:\n        return event['message']\n    \n    # Check in detail field (common in some event sources)\n    if 'detail' in event and isinstance(event['detail'], dict):\n        if 'message' in event['detail']:\n            return event['detail']['message']\n    \n    # Check in Records array (SNS, SQS format)\n    if 'Records' in event and isinstance(event['Records'], list):\n        for record in event['Records']:\n            if isinstance(record, dict):\n                if 'message' in record:\n                    return record['message']\n                if 'Sns' in record and 'Message' in record['Sns']:\n                    return record['Sns']['Message']\n                if 'body' in record:\n                    return record['body']\n    \n    # Check in body field (SQS format)\n    if 'body' in event:\n        return event['body']\n    \n    return None\n",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS CloudWatch log event and extracts the message field from nested event data",
#       "format": "python",
#       "solution_criteria": "Create a function that safely handles JSON parsing, accesses nested dictionaries, and returns the message string. Should include basic error handling for missing or malformed data."
#     },
#     "score": 8.5,
#     "reasoning": "The solution meets the specified criteria by safely handling JSON parsing, accessing nested dictionaries, and including error handling for missing/malformed data. The function demonstrates solid defensive programming with type checking and multiple fallback paths covering standard AWS event formats. However, it falls short of production-grade quality due to overly broad exception handling that masks real errors, limited edge case coverage, and no mechanism to handle serialized JSON within message fields (a common real-world scenario). The implementation is functional for basic use cases but would benefit from more granular error handling and comprehensive testing."
#   }
# ]

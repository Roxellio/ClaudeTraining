# %%
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic() 
model = "claude-sonnet-4-6"

# Make initial list of messages
messages = []

def add_user_message(messages, text):
  user_message = {
    "role": "user", 
    "content": text
  }
  messages.append(user_message)

def add_assistant_message(messages, text):
  assistant_message = {
    "role": "assistant",
    "content": text
  }
  messages.append(assistant_message)

def chat(messages):
  message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=messages
  )
  return message.content[0].text

# Use a 'while True' loop to run chatbot infinitely
while True:
  # Get user input
  user_input = input("> ")
  print(">", user_input)

  # TODO:
  # Add user input to the list of messages
  # Call Claude with the chat function
  # Add generated text to the list of messages
  # Print the generated text
  add_user_message(messages, user_input)
  answer = chat(messages)
  add_assistant_message(messages, answer)
  print("---")
  print(answer)
  print("---")
  # final_answer = chat(messages)

  # print(">", final_answer)
# Out:
# > hi there
# ---
# Hi! How are you doing? Is there something I can help you with today? 😊
# ---
# > updog
# ---
# What's updog? 😄
#
# (I see what you did there! Classic joke setup. I'll play along - what IS updog?)
# ---

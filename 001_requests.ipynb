# %%
# Install dependencies
# %pip install anthropic python-dotenv
# Out:
# ...
#    ---------------------------------------- 0.0/923.8 kB ? eta -:--:--
#    ---------------------------------------- 923.8/923.8 kB 13.1 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 27.3 MB/s  0:00:00
# ...
#
#    ----- ----------------------------------  2/16 [python-dotenv]
#    ----- ----------------------------------  2/16 [python-dotenv]
#    ------- --------------------------------  3/16 [pydantic-core]
#    ---------- -----------------------------  4/16 [jiter]
#    ------------ ---------------------------  5/16 [idna]
#    ------------ ---------------------------  5/16 [idna]
#    --------------- ------------------------  6/16 [h11]
#    --------------- ------------------------  6/16 [h11]
#    ----------------- ----------------------  7/16 [docstring-parser]
#    ---------------------- -----------------  9/16 [certifi]
#    --------------------------- ------------ 11/16 [pydantic]
# ...

# %%
# Load env variables

# %%
# Create an API Client

# %%
# Make a request

# %%
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-6"

# Make initial list of messages
messages = []

def add_user_message(messages, text):
  user_message = {
    "role": "user", 
    "content": text
  }
  messages.append(user_message)

def add_assistant_message(messages, text):
  assistant_message = {
    "role": "user",
    "content": text
  }
  messages.append(assistant_message)

def chat(messages):
  message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=messages
  )
  return message.content[0].text

# Use a 'while True' loop to run chatbot infinitely
while True:
  # Get user input
  user_input = input("> ")
  print(">", user_input)

  # TODO:
  # Add user input to the list of messages
  # Call Claude with the chat function
  # Add generated text to the list of messages
  # Print the generated text
  add_user_message(messages, user_input)
  answer = chat(messages)
  add_assistant_message(messages, answer)
  print("---")
  print(answer)
  print("---")
  # final_answer = chat(messages)

  # print(">", final_answer)
# Out:
# > What is lorem ipsum
# > ## Lorem Ipsum
#
# **Lorem ipsum** is a **placeholder text** commonly used in graphic design, publishing, and web development.
#
# ### What it is:
# - It's dummy text used to fill space when the actual content isn't available yet
# - It allows designers to focus on **visual elements** (layout, fonts, spacing) without being distracted by readable content
#
# ### Where it comes from:
# - It's derived from a work by the Roman philosopher and statesman **Cicero**, written in **45 BC** (*De Finibus Bonorum et Malorum*)
# - The text has been **scrambled and altered**, so it's not a direct translation
#
# ### Example:
# > *"Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua..."*
#
# ### Why it's used:
# - Readers are less distracted by **readable text**
# - It mimics the **look of real text** with varied letter lengths
# - It has been a **standard in the industry** since the 1500s
#
# It became widely popular in the **1980s** with desktop publishing software like **Aldus PageMaker**.
# > list me names of TMNT
# > # Teenage Mutant Ninja Turtles (TMNT)
#
# Here are the **four main turtles**:
#
# | Name | Color | Weapon | Named After |
# |------|-------|--------|-------------|
# | **Leonardo** | 🔵 Blue | Katana swords | Leonardo da Vinci |
# | **Donatello** | 🟣 Purple | Bo staff | Donatello (sculptor) |
# | **Raphael** | 🔴 Red | Sai daggers | Raphael (painter) |
# | **Michelangelo** | 🟠 Orange | Nunchucks | Michelangelo |
#
# ---
#
# ### Key Facts:
# - All four are named after **Renaissance artists**
# - Their sensei/father figure is **Splinter** (a rat)
# - Their main enemy is **Shredder**
# - They love **pizza** 🍕
# - They live in the **sewers of New York City**
# >
# > ## The Four TMNT Names:
#
# 1. **Leonardo** (Leo) 🔵
# 2. **Donatello** (Donnie) 🟣
# 3. **Raphael** (Raph) 🔴
# 4. **Michelangelo** (Mikey) 🟠
#
# All named after **Renaissance artists**!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 37
#      33
#      34 # Use a 'while True' loop to run chatbot infinitely
#      35 while True:
#      36   # Get user input
# ---> 37   user_input = input("> ")
#      38   print(">", user_input)
#      39
#      40   # TODO:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

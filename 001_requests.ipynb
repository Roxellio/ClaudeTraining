# %%
# Install dependencies
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in c:\Users\Roger\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (0.109.2)
# Requirement already satisfied: python-dotenv in c:\Users\Roger\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\Users\Roger\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (4.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Users\Roger\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\Users\Roger\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\Users\Roger\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\Users\Roger\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\Users\Roger\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio in c:\Users\Roger\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in C:\Users\Roger\AppData\Roaming\Python\Python314\site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\Users\Roger\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anyio<5,>=3.5.0->anthropic) (3.18)
# Requirement already satisfied: certifi in c:\Users\Roger\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\Users\Roger\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\Roger\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\Roger\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\Roger\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\Roger\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load env variables
import os
from dotenv import load_dotenv

load_dotenv()
print("ANTHROPIC_API_KEY:", os.getenv("ANTHROPIC_API_KEY"))
# Out:
# True

# %%
# Create an API Client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnnet-4-0"  # or "claude-sonnnet-4-0-20240926" for the latest version
client

# %%
# Make a request
message = client.messages.create(
  model=model,
  max_tokens=1000,
  messages=[
    {
      "role": "user",
      "content": "What is quantum computing? Answer in one sentence"
    }
  ]
)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Make a request
# ----> 2 message = client.messages.create(
#       3   model=model,
#       4   max_tokens=1000,
#       5   messages=[
#
# File c:\Users\Roger\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\anthropic\_utils\_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File c:\Users\Roger\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\anthropic\resources\messages\messages.py:1009, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#    1002 if model in MODELS_TO_WARN_WITH_THINKING_ENABLED and thinking and thinking["type"] == "enabled":
#    1003     warnings.warn(
#    1004         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    1005         UserWarning,
#    1006         stacklevel=3,
#    1007     )
# -> 1009 return self._post(
#    1010     "/v1/messages",
#    1011     body=maybe_transform(
#    1012         {
#    1013             "max_tokens": max_tokens,
#    1014             "messages": messages,
#    1015             "model": model,
#    1016             "cache_control": cache_control,
#    1017             "container": container,
#    1018             "inference_geo": inference_geo,
#    1019             "metadata": metadata,
#    1020             "output_config": output_config,
#    1021             "service_tier": service_tier,
#    1022             "stop_sequences": stop_sequences,
#    1023             "stream": stream,
#    1024             "system": system,
#    1025             "temperature": temperature,
#    1026             "thinking": thinking,
#    1027             "tool_choice": tool_choice,
#    1028             "tools": tools,
#    1029             "top_k": top_k,
#    1030             "top_p": top_p,
#    1031         },
#    1032         message_create_params.MessageCreateParamsStreaming
#    1033         if stream
#    1034         else message_create_params.MessageCreateParamsNonStreaming,
#    1035     ),
#    1036     options=make_request_options(
#    1037         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1038     ),
#    1039     cast_to=Message,
#    1040     stream=stream or False,
#    1041     stream_cls=Stream[RawMessageStreamEvent],
#    1042 )
#
# File c:\Users\Roger\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\anthropic\_base_client.py:1535, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1526     warnings.warn(
#    1527         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1528         "Please pass raw bytes via the `content` parameter instead.",
#    1529         DeprecationWarning,
#    1530         stacklevel=2,
#    1531     )
#    1532 opts = FinalRequestOptions.construct(
#    1533     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1534 )
# -> 1535 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Roger\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\anthropic\_base_client.py:1194, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1191     if not response.is_closed:
#    1192         response.read()
# -> 1194     raise self._make_status_error_from_response(response) from None
#    1196 raise RuntimeError("could not resolve response (should never happen)")
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'Your credit balance is too low to access the Anthropic API. Please go to Plans & Billing to upgrade or purchase credits.'}, 'request_id': 'req_011CcAxhKyHGLtgjqLgGQwaq'}
